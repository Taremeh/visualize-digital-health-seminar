# %% [markdown]
# # General Statistics Overview

# %% [markdown]
# ## Import data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# define file paths
filepath = "ClinicalMarkers_final.csv"
# load data frame
df = pd.read_csv(filepath)

df
# Out:
#     Record   Age     sex              disease_type    Id
# 0        1  1971  Female        Late Disease Stage  3389
# 1        2  1997  Female       Early Disease Stage  4349
# 2        3  1981  Female        Late Disease Stage  6155
# 3        4  1973  Female       Early Disease Stage  9173
# 4        5  1981  Female       Early Disease Stage  2815
# 5        6  1977    Male        Late Disease Stage  9085
# 6        7  2005  Female       Early Disease Stage  9501
# 7        8  1975    Male  Fast Disease Progression  6947
# 8        9  1977  Female        Late Disease Stage  6661
# 9       10  1976    Male       Early Disease Stage  1556
# 10      11  1978  Female       Early Disease Stage  2854
# 11      12  1966    Male        Late Disease Stage  2589
# 12      13  1978    Male  Fast Disease Progression  7183
# 13      14  1976  Female       Early Disease Stage  4457
# 14      15  1987  Female       Early Disease Stage  7928
# ...

# %% [markdown]
# ## General Statistics

# %%
# Display general statistics
df.describe(include='all')
# Out:
#            Record          Age     sex        disease_type           Id
# count   44.000000    44.000000      44                  44    44.000000
# unique        NaN          NaN       2                   3          NaN
# top           NaN          NaN  Female  Late Disease Stage          NaN
# freq          NaN          NaN      29                  19          NaN
# mean    22.977273  1977.795455     NaN                 NaN  5782.795455
# std     13.284873     8.705998     NaN                 NaN  2469.315107
# min      1.000000  1958.000000     NaN                 NaN  1120.000000
# 25%     11.750000  1972.750000     NaN                 NaN  3898.500000
# 50%     22.500000  1978.000000     NaN                 NaN  6066.000000
# 75%     34.250000  1982.250000     NaN                 NaN  7945.000000
# max     45.000000  2005.000000     NaN                 NaN  9926.000000

# %% [markdown]
# ### Age statistics

# %%
# Convert Age column to integers
df['Age'].describe()
# Out:
# count      44.000000
# mean     1977.795455
# std         8.705998
# min      1958.000000
# 25%      1972.750000
# 50%      1978.000000
# 75%      1982.250000
# max      2005.000000
# Name: Age, dtype: float64

# %%
# Plot age distribution
plt.figure(figsize=(12, 4))
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Year of Birth')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Sex Statistics

# %%
# Sex statistics
sex_counts = df['sex'].value_counts()
sex_counts
# Out:
# Female    29
# Male      15
# Name: sex, dtype: int64

# %%
# Plot sex counts
plt.figure(figsize=(4, 4))
sex_counts.plot(kind='bar', color=['lightcoral', 'lightblue'])
plt.title('Sex Counts')
plt.xlabel('Sex')
plt.ylabel('Counts')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Disease Statistics

# %%
# Disease_type statistics
disease_counts = df["disease_type"].value_counts()
disease_counts
# Out:
# Late Disease Stage          19
# Early Disease Stage         18
# Fast Disease Progression     7
# Name: disease_type, dtype: int64

# %%
# Plot disease counts
plt.figure(figsize=(12, 4))
disease_counts.plot(kind='bar', color=['lightgreen', 'lightcoral', 'lightblue'])
plt.title('Disease Type Counts')
plt.xlabel('Disease Type')
plt.ylabel('Counts')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
